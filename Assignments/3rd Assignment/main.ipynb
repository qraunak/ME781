# %% [markdown]
# ##### Write a Python program that takes a 3D point as an input and calculates its Euclidean norm and Mahalanobis norm from the center of the two clusters of data given in the attachment. Visualize the clusters and the input data point in a 3D plot.

# %%
import pandas as pd
import math
import numpy as np

# %%
df1 = pd.read_csv('3D_cluster1.csv')
df1 = df1.to_numpy()
df1
# Out:
# array([[ 3.35298026, 20.2771002 , 13.8754487 ],
#        [11.24464507, 21.89848195, 15.16543545],
#        [ 5.76887738, 19.36887766, 14.34909674],
#        [18.54011395, 19.84338744, 15.92822873],
#        [12.63685455, 20.34697112, 15.54954282],
#        [10.5146924 , 20.9452895 , 14.52320382],
#        [13.5193979 , 20.33746107, 14.17870926],
#        [29.29671811, 19.02183674, 14.4933235 ],
#        [15.40572584, 21.16089919, 15.35128616],
#        [ 2.36428248, 19.84676453, 15.9963063 ],
#        [13.13026386, 19.69774217, 15.56320067],
#        [11.52323604, 20.01044249, 14.72223527],
#        [32.89273026, 18.9691162 , 15.21274112],
#        [ 9.62492399, 20.18528098, 14.51822777],
#        [11.65481477, 20.29447513, 15.14381458],
#        [31.99174789, 21.77642433, 13.70611905],
#        [ 4.4091439 , 21.50727593, 16.06434092],
#        [19.52143066, 19.17943343, 16.44368617],
#        [17.38226614, 19.81834411, 15.62928663],
#        [ 4.71617808, 20.72918632, 14.69093662],
#        [ 9.01166248, 19.86752198, 16.9003271 ],
#        [11.42878215, 19.86765138, 14.6645242 ],
#        [ 3.68841704, 20.00644541, 13.78892215],
#        [22.00613887, 19.97831069, 15.94529202],
#        [-5.81365781, 19.26141375, 14.98582594],
#        [13.28836965, 19.56580001, 13.8540747 ],
#        [16.98196981, 19.06079151, 15.53365236],
#        [ 9.3781908 , 20.58700057, 14.06025758],
#        [ 7.34319837, 22.37270524, 15.66213317],
#        [ 8.08701722, 20.44406364, 13.62395452],
#        [20.58376555, 18.85315809, 16.61122112],
#        [24.61733635, 20.35718378, 13.89099012],
#        [ 4.32833515, 19.91194591, 15.45410678],
#        [25.46771744, 19.43471207, 15.20355495],
#        [15.48557876, 18.88337556, 13.44378012],
#        [-0.9365248 , 19.88229183, 14.52791446],
#        [-2.72055588, 19.61010613, 15.68339338],
#        [13.57885755, 19.91825893, 13.75873045],
#        [18.74038285, 18.28460267, 15.2008589 ],
#        [ 7.45757635, 19.96251314, 16.03083632],
#        [ 4.88003163, 19.57421795, 13.18390043],
#        [15.456374  , 19.53445502, 15.57666761],
#        [ 9.02599375, 21.64348768, 15.93512863],
#        [10.76760901, 20.31277242, 14.7528123 ],
#        [20.37637276, 19.67899674, 15.20356316],
#        [18.39168653, 19.0362434 , 13.60025834],
#        [32.40148064, 18.55325045, 14.47637048],
#        [18.26899936, 20.116962  , 15.51065209],
#        [12.75534188, 20.41153119, 15.01952083],
#        [20.22198898, 19.49601365, 15.06196251],
#        [-1.19280002, 20.63118309, 15.51026959],
#        [34.94756505, 20.89755712, 13.92737961],
#        [17.32915083, 20.51085663, 14.27165464],
#        [ 9.64034837, 21.45374115, 15.04961348],
#        [ 7.67790176, 20.08867094, 14.71430408],
#        [27.14657018, 22.83755817, 14.24730763],
#        [21.25584515, 20.72333221, 20.77357774],
#        [41.44656804, 16.50493737, 19.46821502],
#        [25.2747901 , 17.86821751, 18.96251601],
#        [25.59156827, 18.14330605, 19.54128475],
#        [22.46913015, 19.46182646, 14.56622198],
#        [30.69579415, 19.64600043, 14.72118677],
#        [22.48835481, 22.46150321, 19.72254859],
#        [28.23665314, 22.57456801, 21.72405916],
#        [23.54421447, 20.38814393, 22.64247692],
#        [21.10311541, 21.74427372, 17.90240765],
#        [19.88809204, 22.24937954, 19.93293473],
#        [32.31824397, 24.83923119, 18.2126464 ],
#        [29.80366925, 16.32683067, 16.66365229],
#        [20.21823565, 13.75766383, 19.94418294],
#        [24.90437851, 13.94218234, 18.57976029],
#        [33.06737855, 22.1519023 , 20.88579906],
#        [31.64594357, 19.31473081, 18.91939082],
#        [13.00862206, 13.91682735, 21.24995257],
#        [31.77360564, 33.46270704, 13.00620041],
#        [21.46079462, 27.85880723, 20.20554797]])

# %%
center1= np.mean(df1,axis=0)
center1
# Out:
# array([14.29567941, 19.89971   , 14.88743356])

# %%
center2= np.mean(df2,axis=0)
center2
# Out:
# array([24.36679023, 20.81699166, 19.67764138])

# %%
cov1 =np.cov(df1, rowvar=False)
cov1
# Out:
# array([[ 9.00708840e+01, -7.08734326e-01,  1.38232206e-01],
#        [-7.08734326e-01,  1.08315591e+00, -4.84640089e-02],
#        [ 1.38232206e-01, -4.84640089e-02,  8.74028311e-01]])

# %%
cov2 = np.cov(df2, rowvar=False)
cov2
# Out:
# array([[27.32255588,  2.74651915,  1.58742997],
#        [ 2.74651915, 22.16926548, -2.85286442],
#        [ 1.58742997, -2.85286442, 18.93493102]])

# %%
def euclidean_norm(point, center):
    x1, x2= point[0],center[0]
    y1, y2= point[1],center[1]
    z1, z2= point[2],center[2]
    distance = math.sqrt((x1-x2)**2 + (y1-y2)**2 + (z1-z2)**2)
    return distance

# %%
def mahalanobis_norm(point, center, cov_matrix):
    diff = point - center
    inv_cov_matrix = np.linalg.inv(cov_matrix)
    return np.sqrt(np.dot(np.dot(diff.T, inv_cov_matrix), diff))

# %%
x =float(input("Enter x Coordinate: "))
y =float(input("Enter y Coordinate: "))
z =float(input("Enter x Coordinate: "))
point =np.array([x,y,z])

# %%
euclidean_norm1 = euclidean_norm(point, center1)
euclidean_norm2 = euclidean_norm(point, center2)

# %%
mahalanobis_norm1 = mahalanobis_norm(point, center1, cov1)
mahalanobis_norm2 = mahalanobis_norm(point, center2, cov2)

# %%
print(f"Euclidean Norm from Center of Cluster 1: {euclidean_norm1}")
print(f"Euclidean Norm from Center of Cluster 2: {euclidean_norm2}")
print(f"Mahalanobis Norm from Center of Cluster 1: {mahalanobis_norm1}")
print(f"Mahalanobis Norm from Center of Cluster 2: {mahalanobis_norm2}")
# Out:
# Euclidean Norm from Center of Cluster 1: 24.39131098259556
# Euclidean Norm from Center of Cluster 2: 33.39938947661772
# Mahalanobis Norm from Center of Cluster 1: 20.81112378120023
# Mahalanobis Norm from Center of Cluster 2: 6.749315967987916
